# %% [markdown]
# # Live Corpus Stats

# %%
import os
from dotenv import load_dotenv
import pandas as pd
from dataviz_utils import plot_distribution
from copy import deepcopy
import time

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
timestamp = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())
print("Last updated:", timestamp)
# Out:
# Last updated: 2025-11-24 23:45:02

# %%
load_dotenv()
sheet_id = os.getenv("GOOGLE_SHEETS_ID")
sheet_name = os.getenv("GOOGLE_SHEETS_NAME")
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
df = pd.read_csv(url)
display(df.head())
# Out:
#    Id  Type BaseFormat        Source Authors                        Title  \
# 0   1  docs    webpage  Hugging Face     NaN                         LoRA
# 1   2  docs    webpage  Hugging Face     NaN  PEFT (Hugging Face library)
# 2   3  docs    webpage  Hugging Face     NaN  PEFT (Hugging Face library)
# 3   4  docs    webpage  Hugging Face     NaN  PEFT (Hugging Face library)
# 4   5  docs    webpage  Hugging Face     NaN  PEFT (Hugging Face library)
#
#                                                  URL  PageNumber  \
# 0  https://huggingface.co/docs/peft/main/en/conce...         NaN
# 1     https://huggingface.co/docs/peft/main/en/index         1.0
# 2  https://huggingface.co/docs/peft/main/en/quick...         2.0
# 3   https://huggingface.co/docs/peft/main/en/install         3.0
# 4  https://huggingface.co/docs/peft/main/en/tutor...         4.0
#
#                         PageTitle            _Topics  \
# 0                             NaN  LoRA; Fine-Tuning
# ...

# %%
print("Dataframe shape:", df.shape)
# Out:
# Dataframe shape: (37, 12)

# %% [markdown]
# ## Macro Statistics

# %%
# Source Distribution
plot_distribution(df, 'Source')

# Type Distribution
plot_distribution(df, 'Type')

# Frameworks Distribution
plot_distribution(df, '_Frameworks', explode=True)

# Topics Distribution
plot_distribution(df, '_Topics', explode=True, top_k=10)
